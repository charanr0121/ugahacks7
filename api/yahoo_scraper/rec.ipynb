# %%
import pandas as pd 
import numpy as np

# %%
esg = pd.read_csv("D:/ugahacks7/api/yahoo_scraper/esg.csv", index_col = 0)
esg
# Out:
#     symbols                                               link  score  \
# 0      AAPL  https://www.morningstar.com/stocks/xnas/AAPL/s...      4
# 1      ABNB  https://www.morningstar.com/stocks/xnas/ABNB/s...      3
# 2       ACB  https://www.morningstar.com/stocks/xnas/ACB/su...      2
# 3     ACGLO  https://www.morningstar.com/stocks/xnas/ACGLO/...      3
# 4       ADP  https://www.morningstar.com/stocks/xnas/ADP/su...      4
# ..      ...                                                ...    ...
# 132     PEP  https://www.morningstar.com/stocks/xnas/PEP/su...      4
# 133    PETQ  https://www.morningstar.com/stocks/xnas/PETQ/s...      3
# 134     PFG  https://www.morningstar.com/stocks/xnas/PFG/su...      4
# 135    PHAR  https://www.morningstar.com/stocks/xnas/PHAR/s...      3
# 136    PODD  https://www.morningstar.com/stocks/xnas/PODD/s...      2
#
#                                               incident  \
# 0    Incidents: Business Ethics, Social Supply Chai...
# 1    Incidents: Business Ethics, Customer, Society ...
# 2                                Incidents: Governance
# 3                 Incidents: Business Ethics, Customer
# 4                        Incidents: Employee, Customer
# ..                                                 ...
# 132                     Incidents: Social Supply Chain
# 133                                Incidents: Customer
# 134  Incidents: Product & Service, Business Ethics,...
# 135               Incidents: Business Ethics, Customer
# 136               Incidents: Business Ethics, Customer
#
#                                 issue1                        issue2  \
# 0                      Business Ethics                 Human Capital
# 1                        Human Capital       Data Privacy & Security
# 2                   Product Governance  Emissions, Effluents & Waste
# 3                   Product Governance               ESG Integration
# 4                        Human Capital       Data Privacy & Security
# ..                                 ...                           ...
# 132  E&S Impact of Products & Services                  Human Rights
# 133                                  —                             —
# 134                 Product Governance       Data Privacy & Security
# 135                 Product Governance                 Human Capital
# 136                      Human Capital          Bribery & Corruption
#
#                        issue3  env  soc  gov
# 0     Data Privacy & Security    0    2    1
# 1             Business Ethics    0    2    1
# 2    Access to Basic Services    1    1    1
# 3                  Financials    1    0    2
# 4             Business Ethics    0    2    1
# ..                        ...  ...  ...  ...
# 132              Supply Chain    1    0    0
# 133                         —    0    0    0
# 134           ESG Integration    1    1    1
# 135           Business Ethics    0    1    2
# 136        Product Governance    0    1    2
#
# [137 rows x 10 columns]

# %%
#find average annualized returns over last two years for all stocks 
df = pd.read_csv("../../data/all_stocks.csv")
tickers = esg["symbols"].to_list()
def avg_returns(ticker): 
    stock = df[df.ticker == ticker]
    price = stock.close_price
    return_1 = (price.iloc[len(price) - 1] - price.iloc[len(price)//2]) / price.iloc[len(price)//2]
    return_2 = (price.iloc[len(price)//2] - price.iloc[0]) / price.iloc[0]
    return np.mean([return_1, return_2])

esg["avg_returns"] = esg.apply(lambda row: avg_returns(row.symbols), axis = 1)

# %%
esg
# Out:
#     symbols                                               link  score  \
# 0      AAPL  https://www.morningstar.com/stocks/xnas/AAPL/s...      4
# 1      ABNB  https://www.morningstar.com/stocks/xnas/ABNB/s...      3
# 2       ACB  https://www.morningstar.com/stocks/xnas/ACB/su...      2
# 3     ACGLO  https://www.morningstar.com/stocks/xnas/ACGLO/...      3
# 4       ADP  https://www.morningstar.com/stocks/xnas/ADP/su...      4
# ..      ...                                                ...    ...
# 132     PEP  https://www.morningstar.com/stocks/xnas/PEP/su...      4
# 133    PETQ  https://www.morningstar.com/stocks/xnas/PETQ/s...      3
# 134     PFG  https://www.morningstar.com/stocks/xnas/PFG/su...      4
# 135    PHAR  https://www.morningstar.com/stocks/xnas/PHAR/s...      3
# 136    PODD  https://www.morningstar.com/stocks/xnas/PODD/s...      2
#
#                                               incident  \
# 0    Incidents: Business Ethics, Social Supply Chai...
# 1    Incidents: Business Ethics, Customer, Society ...
# 2                                Incidents: Governance
# 3                 Incidents: Business Ethics, Customer
# 4                        Incidents: Employee, Customer
# ..                                                 ...
# 132                     Incidents: Social Supply Chain
# 133                                Incidents: Customer
# 134  Incidents: Product & Service, Business Ethics,...
# 135               Incidents: Business Ethics, Customer
# 136               Incidents: Business Ethics, Customer
#
#                                 issue1                        issue2  \
# 0                      Business Ethics                 Human Capital
# 1                        Human Capital       Data Privacy & Security
# 2                   Product Governance  Emissions, Effluents & Waste
# 3                   Product Governance               ESG Integration
# 4                        Human Capital       Data Privacy & Security
# ..                                 ...                           ...
# 132  E&S Impact of Products & Services                  Human Rights
# 133                                  —                             —
# 134                 Product Governance       Data Privacy & Security
# 135                 Product Governance                 Human Capital
# 136                      Human Capital          Bribery & Corruption
#
#                        issue3  env  soc  gov  avg_returns
# 0     Data Privacy & Security    0    2    1     0.461116
# 1             Business Ethics    0    2    1     0.151757
# 2    Access to Basic Services    1    1    1    -0.517811
# 3                  Financials    1    0    2    -0.039321
# 4             Business Ethics    0    2    1     0.060308
# ..                        ...  ...  ...  ...          ...
# 132              Supply Chain    1    0    0     0.085625
# 133                         —    0    0    0    -0.241162
# 134           ESG Integration    1    1    1     0.152939
# 135           Business Ethics    0    1    2    -0.266119
# 136        Product Governance    0    1    2     0.072425
#
# [137 rows x 11 columns]

# %%
customer_values = ["Data Privacy", "Transparency", "Environmental Impact"] 

def match_score(row, customer_values): 
    value_to_risk_map = {
        "Ethical Business": "Business Ethics",
        "Education": "Human Capital",
        "Data Privacy": "Data Privacy & Security",
        "Following Regulation": "Product Governance",
        "Anti-pollution": "Emissions, Effluent, and Waste",
        "Equity": "Access to Basic Services",
        "Sustainability": "ESG Integration",
        "Transparency": "Financials",
        "Carbon Footprint": "Carbon",
        "Worker Rights & Protection": "Occupational Health & Safety",
        "Anti-corruption": "Bribery & Corruption",
        "Environmental Impact": "E&S Impact of Products & Services", 
        "Human Rights": "Human Rights",
        "Supplier Sustainability": "Supply Chain",
        "Land Preservation": "L& Use & Biodiversity",
        "Sustainable Products": "Products & Services"
    } #value to risk map

    business_risk = [row.issue1, row.issue2, row.issue3] 
    risk_score = 0
    for value in customer_values:
        if value_to_risk_map[value] in business_risk: 
            risk_score += 1

    return 3 - risk_score

esg["match_score"] = esg.apply(lambda row: match_score(row, customer_values), axis = 1)

# %%
esg["weighted_rec"] = esg["avg_returns"]/esg["avg_returns"].max()*10 + esg["match_score"] + esg["score"]

# %%
esg.sort_values(by="weighted_rec", ascending = False)[:10].symbols
# Out:
# 28     BLNK
# 105    MRNA
# 107    MTCH
# 19     AVNW
# 72     HEAR
# 43     CTRN
# 17     ARCB
# 118    NVDA
# 62     FOSL
# 15      AMD
# Name: symbols, dtype: object
